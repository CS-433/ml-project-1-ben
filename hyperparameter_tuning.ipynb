# %%
from hyperparameter_tuning import *


# Files 
x_train_csv = "dataset/x_train.csv"
y_train_csv = "dataset/y_train.csv"
x_test_csv = "dataset/x_test.csv"

# %% [markdown]
# ### Additional grid search

# %% [markdown]
# **Different feature combinations: augmented and reduced dictionary**

# %%
features_dict = {
    # Binary variables
    'BPMEDS': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'TOLDHI2': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'DIABETE3': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'HLTHPLN1': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'QLACTLM2': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'EXERANY2': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'ADDEPEV2': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'ASTHMA3': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'SMOKE100': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'CVDSTRK3': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'HAVARTH3': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'CHCCOPD1': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'SEX': {'type': 'binary', 'missing_values': [np.nan]},
    'BPHIGH4': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'USEEQUIP': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'BLIND': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'DECIDE': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'DIFFWALK': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'DIFFDRES': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'DIFFALON': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'ALCDAY5': {'type': 'binary', 'missing_values': [np.nan]},
    'CHECKUP1': {'type': 'binary', 'missing_values': [np.nan]},
    'STRENGTH': {'type': 'binary', 'missing_values': [np.nan]},
    'AVG_FRUITS_VEGS': {'type': 'binary', 'missing_values': [np.nan]},
    


    # Categorical variable
    '_RACEGR3': {
        'type': 'categorical',
        'missing_values': [9, np.nan],
        'categories': [1, 2, 3, 4, 5]
    },

    # Numeric variables
    'BMI': {'type': 'numeric', 'missing_values': [7777, 9999, np.nan], 'range': (1, 4)},
    'MENTHLTH': {'type': 'numeric', 'missing_values': [77, 99, np.nan], 'map_value': {88: 0}, 'range': (1, 30)},
    '_AGEG5YR': {'type': 'numeric', 'missing_values': [14, np.nan], 'range': (1, 13)},
    'PHYSHLTH': {'type': 'numeric', 'missing_values': [77, 99, np.nan], 'map_value': {88: 0}, 'range': (1, 30)}
}
features_dict_big = {
    # Binary variables
    'BPMEDS': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'TOLDHI2': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'DIABETE3': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'HLTHPLN1': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'QLACTLM2': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'EXERANY2': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'ADDEPEV2': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'ASTHMA3': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'SMOKE100': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'CVDSTRK3': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'HAVARTH3': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'CHCCOPD1': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'SEX': {'type': 'binary', 'missing_values': [np.nan]},
    'BPHIGH4': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'USEEQUIP': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'BLIND': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'DECIDE': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'DIFFWALK': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'DIFFDRES': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'DIFFALON': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
    'ALCDAY5': {'type': 'binary', 'missing_values': [np.nan]},
    'CHECKUP1': {'type': 'binary', 'missing_values': [np.nan]},
    'STRENGTH': {'type': 'binary', 'missing_values': [np.nan]},
    'AVG_FRUITS_VEGS': {'type': 'binary', 'missing_values': [np.nan]},
    '_RFBING5': {'type': 'binary', 'missing_values': [9, np.nan]},
     '_AGE65YR': {'type': 'binary', 'missing_values': [ np.nan]},
     '_RFDRHV5': {'type': 'binary', 'missing_values': [9, np.nan]},
     '_TOTINDA': {'type': 'binary', 'missing_values': [9, np.nan]},
     '_PAINDX1': {'type': 'binary', 'missing_values': [9, np.nan]},
     '_PASTRNG': {'type': 'binary', 'missing_values': [9, np.nan]},
     '_PASTAE1': {'type': 'binary', 'missing_values': [9, np.nan]},
     '_FLSHOT6': {'type': 'binary', 'missing_values': [ 9,np.nan]},
     '_PNEUMO2': {'type': 'binary', 'missing_values': [ 9,np.nan]},
     '_AIDTST3': {'type': 'binary', 'missing_values': [9, np.nan]},
     '_RFBMI5': {'type': 'binary', 'missing_values': [9, np.nan]},
     '_HISPANC': {'type': 'binary', 'missing_values': [9, np.nan]},
     '_CASTHM1': {'type': 'binary', 'missing_values': [9, np.nan]},
     '_LTASTH1': {'type': 'binary', 'missing_values': [9, np.nan]},
     '_RFCHOL': {'type': 'binary', 'missing_values': [9, np.nan]},
     '_RFHYPE5': {'type': 'binary', 'missing_values': [9, np.nan]},
     '_HCVU651': {'type': 'binary', 'missing_values': [9, np.nan]},
     '_RFHLTH': {'type': 'binary', 'missing_values': [9, np.nan]},
     'MEDCOST': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
     'BLOODCHO': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
     'ASTHNOW': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
     'CHCSCNCR': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
     'CHCCOPD1': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
     'CHCOCNCR': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
     'CHCKIDNY': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
     'VETERAN3': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
     'INTERNET': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
     'LMTJOIN3': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
     'ARTHDIS2': {'type': 'binary', 'missing_values': [7, 9, np.nan]},
     



    # Categorical variable
    '_RACEGR3': {
        'type': 'categorical',
        'missing_values': [9, np.nan],
        'categories': [1, 2, 3, 4, 5]
    },

    # Numeric variables
    #'_DRNKWEK': {'type': 'numeric', 'missing_values': [99900, np.nan], 'range': (1, 6)},
    '_PAREC1': {'type': 'numeric', 'missing_values': [9, np.nan], 'range': (1, 6)},
    '_PA150R2': {'type': 'numeric', 'missing_values': [ 9,np.nan], 'range': (1, 6)},
    '_PACAT1': {'type': 'numeric', 'missing_values': [9], 'range': (1, 6)},
    'FC60_': {'type': 'numeric', 'missing_values': [ 99900], 'range': (1, 6)},
    'MAXVO2_': {'type': 'numeric', 'missing_values': [ 99900], 'range': (1, 6)},
    'EDUCA': {'type': 'numeric', 'missing_values': [9, np.nan], 'range': (1, 6)},  # Education level
    '_INCOMG': {'type': 'numeric', 'missing_values': [9, np.nan], 'range': (1, 6)},
    'BMI': {'type': 'numeric', 'missing_values': [7777, 9999, np.nan], 'range': (1, 4)},
    'MENTHLTH': {'type': 'numeric', 'missing_values': [77, 99, np.nan], 'map_value': {88: 0}, 'range': (1, 30)},
    '_AGEG5YR': {'type': 'numeric', 'missing_values': [14, np.nan], 'range': (1, 13)},
    'PHYSHLTH': {'type': 'numeric', 'missing_values': [77, 99, np.nan], 'map_value': {88: 0}, 'range': (1, 30)}
}

# %%
# Read x_train and y_train
x_train, features = csv_to_array("dataset/x_train.csv")
Y_train, labels = csv_to_array("dataset/y_train.csv")
x_test , ids = csv_to_array("dataset/x_test.csv", id=True)
# Flatten y_train to convert into 1d array
Y_train = Y_train.flatten()
# Y modification
Y_train = np.where(Y_train == -1, 0, Y_train)

# %%
#  DICT (reduced)
X_train, features = X_preprocessing(x_train, features)
X_train_balanced, Y_train_balanced = balance_dataset(X_train, Y_train)
X_train_transformed = transform_features_column_median(X_train_balanced, features_dict, features)

gamma_values = [ 0.01, 0.001, 0.0005, 0.0001]  # Learning rate
max_iters_values = [250, 500, 1000, 1500]  # Number of iterations
l2_reg_values = [0.2, 0.1, 0.01]  # L2 regularization parameter
batch_size_values = [ 256, 512, 2048]  # Batch sizes for SGD
prob_threshold_values = [0.5]
beta1_values = [0.9]
beta2_values = [0.98]
decay_rates = [0.96]
decay_step_values = [100]

# Initialize a list to store results for each combination
grid_search_results = []
K = 5


# Perform grid search
for gamma, max_iters, batch, param_l2, prob_threshold, beta1, beta2, decay_rate, decay_steps in itertools.product(
        gamma_values, max_iters_values, batch_size_values, l2_reg_values,  prob_threshold_values, beta1_values, beta2_values, decay_rates, decay_step_values):
    
    # Run evaluation with current parameter combination
    F1_score = K_fold_cross_validation_f1_score(X_train_transformed, Y_train_balanced, K, 
       seed=5,
       max_iters=max_iters,
       gamma=gamma,
       reg_norm= ['l2',param_l2],
       prob_threshold=prob_threshold,
       batch_size=batch,
       beta1=beta1,
        beta2=beta2,
        decay_rate=decay_rate, 
        decay_steps=decay_steps
    )

    

    # Store the result and parameters for analysis
    grid_search_results.append({
        'gamma': gamma,
        'max_iters': max_iters,
        'batch_size': batch, 
        'reg_norm': param_l2,
        'prob_threshold': prob_threshold,
        'beta1': beta1,
        'beta2': beta2,
        'decay_rate': decay_rate,
        'decay_steps': decay_steps,
        'F1_score': F1_score
    })
# Out:
# C:\Users\beaiz\AppData\Local\Temp\ipykernel_27308\1134805394.py:1172: RuntimeWarning: Mean of empty slice
#   average_column = np.nanmean(selected_columns, axis=1)
# 100%|██████████| 5/5 [00:29<00:00,  5.96s/it]
# 100%|██████████| 5/5 [00:35<00:00,  7.01s/it]
# 100%|██████████| 5/5 [00:32<00:00,  6.59s/it]
# 100%|██████████| 5/5 [00:26<00:00,  5.31s/it]
# 100%|██████████| 5/5 [00:26<00:00,  5.30s/it]
# 100%|██████████| 5/5 [00:25<00:00,  5.20s/it]
# 100%|██████████| 5/5 [00:21<00:00,  4.38s/it]
# 100%|██████████| 5/5 [00:22<00:00,  4.51s/it]
# 100%|██████████| 5/5 [00:21<00:00,  4.32s/it]
# 100%|██████████| 5/5 [00:55<00:00, 11.11s/it]
# 100%|██████████| 5/5 [01:03<00:00, 12.65s/it]
# 100%|██████████| 5/5 [00:57<00:00, 11.53s/it]
# 100%|██████████| 5/5 [00:42<00:00,  8.59s/it]
# 100%|██████████| 5/5 [00:47<00:00,  9.46s/it]
# 100%|██████████| 5/5 [00:53<00:00, 10.61s/it]
# 100%|██████████| 5/5 [00:43<00:00,  8.78s/it]
# 100%|██████████| 5/5 [00:43<00:00,  8.79s/it]
# 100%|██████████| 5/5 [00:43<00:00,  8.75s/it]
# 100%|██████████| 5/5 [02:08<00:00, 25.63s/it]
# 100%|██████████| 5/5 [01:53<00:00, 22.73s/it]
# 100%|██████████| 5/5 [02:08<00:00, 25.71s/it]
# 100%|██████████| 5/5 [01:46<00:00, 21.23s/it]
# 100%|██████████| 5/5 [01:46<00:00, 21.22s/it]
# 100%|██████████| 5/5 [01:48<00:00, 21.73s/it]
# 100%|██████████| 5/5 [01:30<00:00, 18.10s/it]
# 100%|██████████| 5/5 [01:27<00:00, 17.59s/it]
# 100%|██████████| 5/5 [01:30<00:00, 18.13s/it]
# 100%|██████████| 5/5 [03:16<00:00, 39.21s/it]
# 100%|██████████| 5/5 [00:36<00:00,  7.25s/it]
# 100%|██████████| 5/5 [01:48<00:00, 21.61s/it]
# 100%|██████████| 5/5 [01:47<00:00, 21.48s/it]
# 100%|██████████| 5/5 [01:47<00:00, 21.47s/it]
# 100%|██████████| 5/5 [01:28<00:00, 17.60s/it]
# 100%|██████████| 5/5 [01:27<00:00, 17.54s/it]
# 100%|██████████| 5/5 [01:27<00:00, 17.44s/it]
# 100%|██████████| 5/5 [01:11<00:00, 14.40s/it]
# 100%|██████████| 5/5 [01:12<00:00, 14.49s/it]
# 100%|██████████| 5/5 [01:12<00:00, 14.47s/it]
# 100%|██████████| 5/5 [02:41<00:00, 32.27s/it]
# 100%|██████████| 5/5 [02:44<00:00, 32.92s/it]
# 100%|██████████| 5/5 [02:41<00:00, 32.35s/it]
# 100%|██████████| 5/5 [02:12<00:00, 26.50s/it]
# 100%|██████████| 5/5 [02:12<00:00, 26.50s/it]
# 100%|██████████| 5/5 [02:12<00:00, 26.42s/it]
# 100%|██████████| 5/5 [01:48<00:00, 21.64s/it]
# 100%|██████████| 5/5 [01:49<00:00, 21.84s/it]
# 100%|██████████| 5/5 [01:48<00:00, 21.72s/it]

# %%
# Sort grid search results by F1_score in descending order (best to worst)
sorted_results = sorted(grid_search_results, key=lambda x: x['F1_score'], reverse=True)

# Display sorted results
for i, result in enumerate(sorted_results):
    print(f"Rank {i+1}:")
    print(f"  F1_score: {result['F1_score']}")
    print(f"  gamma: {result['gamma']}")
    print(f"  max_iters: {result['max_iters']}")
    print(f"  batch_size: {result['batch_size']}")
    print(f"  reg_norm: {result['reg_norm']}")
    print(f"  prob_threshold: {result['prob_threshold']}")
    print(f"  beta1: {result['beta1']}")
    print(f"  beta2: {result['beta2']}")
    print(f"  decay_rate: {result['decay_rate']}")
    print(f"  decay_steps: {result['decay_steps']}")
    print("\n")
# Out:
# Rank 1:
#   F1_score: 0.7297562656384822
#   gamma: 0.0001
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 2:
#   F1_score: 0.7297292031551234
#   gamma: 0.0001
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 3:
#   F1_score: 0.7297097504072538
#   gamma: 0.0001
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 4:
#   F1_score: 0.72938087080485
#   gamma: 0.0001
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 5:
#   F1_score: 0.7293283091039728
#   gamma: 0.0001
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 6:
#   F1_score: 0.729222029181132
#   gamma: 0.0001
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 7:
#   F1_score: 0.7291832780186868
#   gamma: 0.01
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 8:
#   F1_score: 0.7290976924689845
#   gamma: 0.001
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 9:
#   F1_score: 0.7286994440482994
#   gamma: 0.001
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 10:
#   F1_score: 0.7286531625934983
#   gamma: 0.0005
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 11:
#   F1_score: 0.7286111650930407
#   gamma: 0.0005
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 12:
#   F1_score: 0.7284280613599299
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 13:
#   F1_score: 0.7281496251770545
#   gamma: 0.0005
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 14:
#   F1_score: 0.727906405760281
#   gamma: 0.001
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 15:
#   F1_score: 0.7278740026059041
#   gamma: 0.001
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 16:
#   F1_score: 0.7276941082968846
#   gamma: 0.01
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 17:
#   F1_score: 0.7274706353666283
#   gamma: 0.001
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 18:
#   F1_score: 0.7272446286563035
#   gamma: 0.0005
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 19:
#   F1_score: 0.7271559834008631
#   gamma: 0.01
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 20:
#   F1_score: 0.727110431156481
#   gamma: 0.001
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 21:
#   F1_score: 0.7269149645836328
#   gamma: 0.001
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 22:
#   F1_score: 0.7266684355111201
#   gamma: 0.0005
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 23:
#   F1_score: 0.726635218248798
#   gamma: 0.0005
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 24:
#   F1_score: 0.7265926900247238
#   gamma: 0.001
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 25:
#   F1_score: 0.726432244811552
#   gamma: 0.01
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 26:
#   F1_score: 0.7262808820364587
#   gamma: 0.001
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 27:
#   F1_score: 0.7261347449339356
#   gamma: 0.001
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 28:
#   F1_score: 0.7260183841488178
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 29:
#   F1_score: 0.7259998160240889
#   gamma: 0.0005
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 30:
#   F1_score: 0.72592280992307
#   gamma: 0.01
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 31:
#   F1_score: 0.7259209535918537
#   gamma: 0.001
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 32:
#   F1_score: 0.7259035080396423
#   gamma: 0.001
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 33:
#   F1_score: 0.725897365411381
#   gamma: 0.0005
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 34:
#   F1_score: 0.7258913471938471
#   gamma: 0.001
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 35:
#   F1_score: 0.7258539694616386
#   gamma: 0.001
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 36:
#   F1_score: 0.7257802338606807
#   gamma: 0.0005
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 37:
#   F1_score: 0.7256807188858405
#   gamma: 0.001
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 38:
#   F1_score: 0.7256569241783298
#   gamma: 0.0005
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 39:
#   F1_score: 0.7256553767623279
#   gamma: 0.001
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 40:
#   F1_score: 0.7256200245784737
#   gamma: 0.01
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 41:
#   F1_score: 0.725585803103032
#   gamma: 0.0005
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 42:
#   F1_score: 0.7255363336689415
#   gamma: 0.0001
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 43:
#   F1_score: 0.7255311755520223
#   gamma: 0.0005
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 44:
#   F1_score: 0.7254856086255324
#   gamma: 0.001
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 45:
#   F1_score: 0.7254799302088326
#   gamma: 0.0005
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 46:
#   F1_score: 0.7254550509339734
#   gamma: 0.001
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 47:
#   F1_score: 0.7254425043194404
#   gamma: 0.01
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 48:
#   F1_score: 0.7254215988638226
#   gamma: 0.0001
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 49:
#   F1_score: 0.7253983491722902
#   gamma: 0.0005
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 50:
#   F1_score: 0.7253824297696885
#   gamma: 0.001
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 51:
#   F1_score: 0.7253797975407915
#   gamma: 0.0005
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 52:
#   F1_score: 0.7253532454858493
#   gamma: 0.001
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 53:
#   F1_score: 0.7253337395616966
#   gamma: 0.0001
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 54:
#   F1_score: 0.7252982634411083
#   gamma: 0.0001
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 55:
#   F1_score: 0.7252931746546094
#   gamma: 0.0005
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 56:
#   F1_score: 0.7252723705336198
#   gamma: 0.001
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 57:
#   F1_score: 0.7252678333814782
#   gamma: 0.0005
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 58:
#   F1_score: 0.72525852543328
#   gamma: 0.001
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 59:
#   F1_score: 0.7252165013622529
#   gamma: 0.0001
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 60:
#   F1_score: 0.7251424581382786
#   gamma: 0.001
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 61:
#   F1_score: 0.7251059143849933
#   gamma: 0.0005
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 62:
#   F1_score: 0.725099934819723
#   gamma: 0.0001
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 63:
#   F1_score: 0.7250499629067436
#   gamma: 0.0005
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 64:
#   F1_score: 0.7250495143581116
#   gamma: 0.0005
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 65:
#   F1_score: 0.7250426867093298
#   gamma: 0.0005
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 66:
#   F1_score: 0.7250361320195868
#   gamma: 0.0005
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 67:
#   F1_score: 0.7250308576004667
#   gamma: 0.0005
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 68:
#   F1_score: 0.7250133777952759
#   gamma: 0.0001
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 69:
#   F1_score: 0.7250008982718841
#   gamma: 0.0005
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 70:
#   F1_score: 0.7249661773950742
#   gamma: 0.001
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 71:
#   F1_score: 0.7249533313876143
#   gamma: 0.001
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 72:
#   F1_score: 0.7249413627290913
#   gamma: 0.0001
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 73:
#   F1_score: 0.7249305286252874
#   gamma: 0.0005
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 74:
#   F1_score: 0.7249065489373792
#   gamma: 0.0005
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 75:
#   F1_score: 0.7248897024267085
#   gamma: 0.0001
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 76:
#   F1_score: 0.724882561824312
#   gamma: 0.0005
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 77:
#   F1_score: 0.7248777754222469
#   gamma: 0.001
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 78:
#   F1_score: 0.7248477583848569
#   gamma: 0.001
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 79:
#   F1_score: 0.7248431405306395
#   gamma: 0.0005
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 80:
#   F1_score: 0.7248095435406996
#   gamma: 0.0005
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 81:
#   F1_score: 0.7247894530906014
#   gamma: 0.01
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 82:
#   F1_score: 0.7247420154381419
#   gamma: 0.001
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 83:
#   F1_score: 0.7247212596544589
#   gamma: 0.001
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 84:
#   F1_score: 0.7247187368102678
#   gamma: 0.001
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 85:
#   F1_score: 0.7246224063754999
#   gamma: 0.0005
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 86:
#   F1_score: 0.7245352610408071
#   gamma: 0.0005
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 87:
#   F1_score: 0.7245165381759067
#   gamma: 0.0005
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 88:
#   F1_score: 0.724503833144456
#   gamma: 0.001
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 89:
#   F1_score: 0.7244591032487009
#   gamma: 0.01
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 90:
#   F1_score: 0.724296743313668
#   gamma: 0.01
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 91:
#   F1_score: 0.7242626291704856
#   gamma: 0.001
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 92:
#   F1_score: 0.724227579171823
#   gamma: 0.0005
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 93:
#   F1_score: 0.7240784069134041
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 94:
#   F1_score: 0.7239479452008889
#   gamma: 0.001
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 95:
#   F1_score: 0.7239123576206998
#   gamma: 0.01
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 96:
#   F1_score: 0.7234260651717999
#   gamma: 0.01
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 97:
#   F1_score: 0.7233846476600299
#   gamma: 0.01
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 98:
#   F1_score: 0.7232487562078369
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 99:
#   F1_score: 0.7231763160971383
#   gamma: 0.01
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 100:
#   F1_score: 0.7217566725716338
#   gamma: 0.01
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 101:
#   F1_score: 0.7216855896684025
#   gamma: 0.001
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 102:
#   F1_score: 0.7214002802181473
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 103:
#   F1_score: 0.7213944338529299
#   gamma: 0.0001
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 104:
#   F1_score: 0.7213440757185509
#   gamma: 0.0001
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 105:
#   F1_score: 0.7212909271861935
#   gamma: 0.0001
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 106:
#   F1_score: 0.7212432771125299
#   gamma: 0.01
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 107:
#   F1_score: 0.7211769802963747
#   gamma: 0.01
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 108:
#   F1_score: 0.7209632755722745
#   gamma: 0.001
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 109:
#   F1_score: 0.7207614856806298
#   gamma: 0.01
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 110:
#   F1_score: 0.7206631694554517
#   gamma: 0.01
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 111:
#   F1_score: 0.7204722030595135
#   gamma: 0.0001
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 112:
#   F1_score: 0.7204558249886827
#   gamma: 0.0001
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 113:
#   F1_score: 0.720451166324002
#   gamma: 0.0001
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 114:
#   F1_score: 0.720448956023594
#   gamma: 0.01
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 115:
#   F1_score: 0.7204466503863968
#   gamma: 0.0001
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 116:
#   F1_score: 0.7204263809160524
#   gamma: 0.0001
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 117:
#   F1_score: 0.7203977782243296
#   gamma: 0.0001
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 118:
#   F1_score: 0.7203314546286418
#   gamma: 0.01
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 119:
#   F1_score: 0.7201576427026799
#   gamma: 0.0001
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 120:
#   F1_score: 0.7201550857798854
#   gamma: 0.0005
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 121:
#   F1_score: 0.7201367119161092
#   gamma: 0.0001
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 122:
#   F1_score: 0.7200914522869828
#   gamma: 0.0001
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 123:
#   F1_score: 0.7200029663842746
#   gamma: 0.0005
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 124:
#   F1_score: 0.7198904653210503
#   gamma: 0.0005
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 125:
#   F1_score: 0.7193595531369676
#   gamma: 0.001
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 126:
#   F1_score: 0.7193431804452726
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 127:
#   F1_score: 0.7191586986626384
#   gamma: 0.0001
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 128:
#   F1_score: 0.7191377582032877
#   gamma: 0.0001
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 129:
#   F1_score: 0.7191374066688023
#   gamma: 0.0001
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 130:
#   F1_score: 0.7188073462381162
#   gamma: 0.01
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 131:
#   F1_score: 0.7184838408485705
#   gamma: 0.01
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 132:
#   F1_score: 0.7167813672487859
#   gamma: 0.01
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 133:
#   F1_score: 0.7158509151624604
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 134:
#   F1_score: 0.7149743562180607
#   gamma: 0.0001
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 135:
#   F1_score: 0.7149743562180607
#   gamma: 0.0001
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 136:
#   F1_score: 0.7149743562180607
#   gamma: 0.0001
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 137:
#   F1_score: 0.7137879027792597
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 138:
#   F1_score: 0.7135572858848922
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 139:
#   F1_score: 0.7134136010652954
#   gamma: 0.01
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 140:
#   F1_score: 0.7131993075539906
#   gamma: 0.01
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 141:
#   F1_score: 0.7116352772151654
#   gamma: 0.01
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 142:
#   F1_score: 0.7053035573359991
#   gamma: 0.0001
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 143:
#   F1_score: 0.7052926365416228
#   gamma: 0.0001
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 144:
#   F1_score: 0.7052925748791422
#   gamma: 0.0001
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100

# %%
#  DICT AUGMENTED
X_train, features = X_preprocessing(x_train, features)
X_train_balanced, Y_train_balanced = balance_dataset(X_train, Y_train)
X_train_transformed = transform_features_column_median(X_train_balanced, features_dict_big, features)

gamma_values = [ 0.01, 0.001, 0.0005, 0.0001]  # Learning rate
max_iters_values = [250, 500, 1000, 1500]  # Number of iterations
l2_reg_values = [0.2, 0.1, 0.01]  # L2 regularization parameter
batch_size_values = [ 256, 512, 2048]  # Batch sizes for SGD
prob_threshold_values = [0.5]
beta1_values = [0.9]
beta2_values = [0.98]
decay_rates = [0.96]
decay_step_values = [100]

# Initialize a list to store results for each combination
grid_search_results = []
K = 5


# Perform grid search
for gamma, max_iters, batch, param_l2, prob_threshold, beta1, beta2, decay_rate, decay_steps in itertools.product(
        gamma_values, max_iters_values, batch_size_values, l2_reg_values,  prob_threshold_values, beta1_values, beta2_values, decay_rates, decay_step_values):
    
    # Run evaluation with current parameter combination
    F1_score = K_fold_cross_validation_f1_score(X_train_transformed, Y_train_balanced, K, 
       seed=5,
       max_iters=max_iters,
       gamma=gamma,
       reg_norm= ['l2',param_l2],
       prob_threshold=prob_threshold,
       batch_size=batch,
       beta1=beta1,
        beta2=beta2,
# 100%|██████████| 5/5 [03:06<00:00, 37.29s/it]
# 100%|██████████| 5/5 [03:06<00:00, 37.30s/it]
# 100%|██████████| 5/5 [03:09<00:00, 37.91s/it]
# 100%|██████████| 5/5 [02:44<00:00, 32.88s/it]
# 100%|██████████| 5/5 [02:42<00:00, 32.55s/it]
# 100%|██████████| 5/5 [02:44<00:00, 32.89s/it]

# %%
# Sort grid search results by F1_score in descending order (best to worst)
sorted_results = sorted(grid_search_results, key=lambda x: x['F1_score'], reverse=True)

# Display sorted results
for i, result in enumerate(sorted_results):
    print(f"Rank {i+1}:")
    print(f"  F1_score: {result['F1_score']}")
    print(f"  gamma: {result['gamma']}")
    print(f"  max_iters: {result['max_iters']}")
    print(f"  batch_size: {result['batch_size']}")
    print(f"  reg_norm: {result['reg_norm']}")
    print(f"  prob_threshold: {result['prob_threshold']}")
    print(f"  beta1: {result['beta1']}")
    print(f"  beta2: {result['beta2']}")
    print(f"  decay_rate: {result['decay_rate']}")
    print(f"  decay_steps: {result['decay_steps']}")
    print("\n")
# Out:
# Rank 1:
#   F1_score: 0.7310476815563055
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 2:
#   F1_score: 0.7306840135353248
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 3:
#   F1_score: 0.7298749236114407
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 4:
#   F1_score: 0.7279765031782957
#   gamma: 0.01
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 5:
#   F1_score: 0.7276688432559046
#   gamma: 0.01
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 6:
#   F1_score: 0.7270683521667805
#   gamma: 0.01
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 7:
#   F1_score: 0.7258410916363827
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 8:
#   F1_score: 0.7258236939621856
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 9:
#   F1_score: 0.7257881201479892
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 10:
#   F1_score: 0.7257818890156109
#   gamma: 0.001
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 11:
#   F1_score: 0.7255635341203958
#   gamma: 0.01
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 12:
#   F1_score: 0.725553372455787
#   gamma: 0.001
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 13:
#   F1_score: 0.7255281050354697
#   gamma: 0.001
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 14:
#   F1_score: 0.7254261109415463
#   gamma: 0.001
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 15:
#   F1_score: 0.7253960199498917
#   gamma: 0.001
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 16:
#   F1_score: 0.7253192285865542
#   gamma: 0.001
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 17:
#   F1_score: 0.725301643552333
#   gamma: 0.01
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 18:
#   F1_score: 0.7252134042122359
#   gamma: 0.0005
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 19:
#   F1_score: 0.7251578250794006
#   gamma: 0.0005
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 20:
#   F1_score: 0.7251564215495898
#   gamma: 0.0005
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 21:
#   F1_score: 0.7251246589509158
#   gamma: 0.01
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 22:
#   F1_score: 0.7248944730195654
#   gamma: 0.001
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 23:
#   F1_score: 0.7246805752253126
#   gamma: 0.001
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 24:
#   F1_score: 0.7246057380945482
#   gamma: 0.0001
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 25:
#   F1_score: 0.7245849841780478
#   gamma: 0.0001
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 26:
#   F1_score: 0.7245847063542314
#   gamma: 0.0001
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 27:
#   F1_score: 0.7244586328683125
#   gamma: 0.0005
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 28:
#   F1_score: 0.7244283820363272
#   gamma: 0.0005
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 29:
#   F1_score: 0.7243715583295466
#   gamma: 0.0005
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 30:
#   F1_score: 0.724347492315888
#   gamma: 0.001
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 31:
#   F1_score: 0.7241635323387466
#   gamma: 0.0001
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 32:
#   F1_score: 0.7241485838862637
#   gamma: 0.0001
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 33:
#   F1_score: 0.7241043444091874
#   gamma: 0.0001
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 34:
#   F1_score: 0.7240974585525347
#   gamma: 0.0001
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 35:
#   F1_score: 0.7240759645752634
#   gamma: 0.0001
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 36:
#   F1_score: 0.7240759645752634
#   gamma: 0.0001
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 37:
#   F1_score: 0.7239581956575927
#   gamma: 0.0005
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 38:
#   F1_score: 0.7238977762401306
#   gamma: 0.0005
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 39:
#   F1_score: 0.7238316931665253
#   gamma: 0.0005
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 40:
#   F1_score: 0.7238154022091589
#   gamma: 0.0001
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 41:
#   F1_score: 0.7238122165159496
#   gamma: 0.0001
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 42:
#   F1_score: 0.7238017850321514
#   gamma: 0.0001
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 43:
#   F1_score: 0.7237909859891476
#   gamma: 0.0001
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 44:
#   F1_score: 0.7237836305813292
#   gamma: 0.0001
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 45:
#   F1_score: 0.7237804491866932
#   gamma: 0.0001
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 46:
#   F1_score: 0.7237729356277789
#   gamma: 0.0005
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 47:
#   F1_score: 0.7236979129153698
#   gamma: 0.0005
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 48:
#   F1_score: 0.7236604889907478
#   gamma: 0.0005
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 49:
#   F1_score: 0.7236130279963059
#   gamma: 0.0001
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 50:
#   F1_score: 0.7236055800670211
#   gamma: 0.0005
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 51:
#   F1_score: 0.7235764696899488
#   gamma: 0.0001
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 52:
#   F1_score: 0.7235460674292347
#   gamma: 0.0001
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 53:
#   F1_score: 0.7235325403218129
#   gamma: 0.0005
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 54:
#   F1_score: 0.7235209242866774
#   gamma: 0.0005
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 55:
#   F1_score: 0.7235132144828847
#   gamma: 0.001
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 56:
#   F1_score: 0.7234974173399902
#   gamma: 0.0005
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 57:
#   F1_score: 0.7234826547194273
#   gamma: 0.0005
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 58:
#   F1_score: 0.7234711177295904
#   gamma: 0.0001
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 59:
#   F1_score: 0.7234594132345956
#   gamma: 0.0001
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 60:
#   F1_score: 0.7234589898319876
#   gamma: 0.0001
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 61:
#   F1_score: 0.7234356257547996
#   gamma: 0.0005
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 62:
#   F1_score: 0.7234156375287586
#   gamma: 0.0005
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 63:
#   F1_score: 0.723407675182939
#   gamma: 0.0005
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 64:
#   F1_score: 0.7234007284093457
#   gamma: 0.001
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 65:
#   F1_score: 0.7233869493763073
#   gamma: 0.0005
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 66:
#   F1_score: 0.7233536263874529
#   gamma: 0.001
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 67:
#   F1_score: 0.7233501882228102
#   gamma: 0.0001
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 68:
#   F1_score: 0.7233196310420735
#   gamma: 0.0001
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 69:
#   F1_score: 0.7233160535721324
#   gamma: 0.0001
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 70:
#   F1_score: 0.7233048461073628
#   gamma: 0.0001
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 71:
#   F1_score: 0.7232851415052247
#   gamma: 0.0001
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 72:
#   F1_score: 0.7232730744126111
#   gamma: 0.0001
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 73:
#   F1_score: 0.7232486899873269
#   gamma: 0.0005
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 74:
#   F1_score: 0.7231808978537957
#   gamma: 0.0001
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 75:
#   F1_score: 0.7231621583912984
#   gamma: 0.0001
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 76:
#   F1_score: 0.723156808300317
#   gamma: 0.0001
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 77:
#   F1_score: 0.7231127125816357
#   gamma: 0.001
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 78:
#   F1_score: 0.723043483732165
#   gamma: 0.0005
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 79:
#   F1_score: 0.7229873656252886
#   gamma: 0.0005
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 80:
#   F1_score: 0.7229738153419759
#   gamma: 0.0005
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 81:
#   F1_score: 0.7229709372993748
#   gamma: 0.01
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 82:
#   F1_score: 0.7229675692937734
#   gamma: 0.0005
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 83:
#   F1_score: 0.72296499686677
#   gamma: 0.0001
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 84:
#   F1_score: 0.7229557006598225
#   gamma: 0.0001
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 85:
#   F1_score: 0.7229500510160751
#   gamma: 0.001
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 86:
#   F1_score: 0.7229403386414781
#   gamma: 0.001
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 87:
#   F1_score: 0.7229314744245039
#   gamma: 0.0001
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 88:
#   F1_score: 0.7229226688168786
#   gamma: 0.001
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 89:
#   F1_score: 0.7229119195561806
#   gamma: 0.001
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 90:
#   F1_score: 0.7228629615441671
#   gamma: 0.0005
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 91:
#   F1_score: 0.7228497969193902
#   gamma: 0.001
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 92:
#   F1_score: 0.7228490072384822
#   gamma: 0.01
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 93:
#   F1_score: 0.7228339735483449
#   gamma: 0.001
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 94:
#   F1_score: 0.7228112926273658
#   gamma: 0.001
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 95:
#   F1_score: 0.7227517603476045
#   gamma: 0.001
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 96:
#   F1_score: 0.7227366197951358
#   gamma: 0.001
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 97:
#   F1_score: 0.7226999791103573
#   gamma: 0.001
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 98:
#   F1_score: 0.7226585574250656
#   gamma: 0.001
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 99:
#   F1_score: 0.7225765101739879
#   gamma: 0.0001
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 100:
#   F1_score: 0.7225737683548263
#   gamma: 0.0001
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 101:
#   F1_score: 0.7225089374689139
#   gamma: 0.0001
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 102:
#   F1_score: 0.7224856957567665
#   gamma: 0.001
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 103:
#   F1_score: 0.7224563169000506
#   gamma: 0.01
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 104:
#   F1_score: 0.7224372792380346
#   gamma: 0.001
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 105:
#   F1_score: 0.722431639412239
#   gamma: 0.001
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 106:
#   F1_score: 0.7223236692280481
#   gamma: 0.0005
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 107:
#   F1_score: 0.7221791140968895
#   gamma: 0.0005
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 108:
#   F1_score: 0.7221649367416246
#   gamma: 0.0005
#   max_iters: 250
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 109:
#   F1_score: 0.7218408308066989
#   gamma: 0.001
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 110:
#   F1_score: 0.7218361203778021
#   gamma: 0.001
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 111:
#   F1_score: 0.7217905895470056
#   gamma: 0.001
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 112:
#   F1_score: 0.7216647244829275
#   gamma: 0.001
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 113:
#   F1_score: 0.7216633299242151
#   gamma: 0.001
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 114:
#   F1_score: 0.7216594671004346
#   gamma: 0.001
#   max_iters: 1000
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 115:
#   F1_score: 0.7214444741156452
#   gamma: 0.0005
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 116:
#   F1_score: 0.7213935277732624
#   gamma: 0.0005
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 117:
#   F1_score: 0.7212938677764505
#   gamma: 0.0005
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 118:
#   F1_score: 0.7211153561857946
#   gamma: 0.0005
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 119:
#   F1_score: 0.7211152367746192
#   gamma: 0.0005
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 120:
#   F1_score: 0.7210893945469883
#   gamma: 0.0005
#   max_iters: 500
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 121:
#   F1_score: 0.719466534973491
#   gamma: 0.01
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 122:
#   F1_score: 0.7193467532432225
#   gamma: 0.01
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 123:
#   F1_score: 0.7192848264342124
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 124:
#   F1_score: 0.7192018696334268
#   gamma: 0.01
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 125:
#   F1_score: 0.7191459752096
#   gamma: 0.01
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 126:
#   F1_score: 0.7191253287150657
#   gamma: 0.01
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 127:
#   F1_score: 0.7189859598007853
#   gamma: 0.001
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 128:
#   F1_score: 0.7189804697516181
#   gamma: 0.001
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 129:
#   F1_score: 0.7189587636890208
#   gamma: 0.01
#   max_iters: 500
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 130:
#   F1_score: 0.7189221404571334
#   gamma: 0.01
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 131:
#   F1_score: 0.7189150955598593
#   gamma: 0.01
#   max_iters: 1000
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 132:
#   F1_score: 0.7189107167848661
#   gamma: 0.001
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 133:
#   F1_score: 0.71890314160667
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 134:
#   F1_score: 0.7186531739595394
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 135:
#   F1_score: 0.7184111917605925
#   gamma: 0.01
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 136:
#   F1_score: 0.7183759431909824
#   gamma: 0.01
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 137:
#   F1_score: 0.7182702946659824
#   gamma: 0.01
#   max_iters: 250
#   batch_size: 2048
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 138:
#   F1_score: 0.7181927564731602
#   gamma: 0.01
#   max_iters: 1000
#   batch_size: 2048
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 139:
#   F1_score: 0.7175881792970615
#   gamma: 0.01
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 140:
#   F1_score: 0.7173650988053534
#   gamma: 0.01
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 141:
#   F1_score: 0.717264431582873
#   gamma: 0.01
#   max_iters: 250
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 142:
#   F1_score: 0.7092658854764666
#   gamma: 0.01
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 143:
#   F1_score: 0.709106997272636
#   gamma: 0.01
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.1
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 144:
#   F1_score: 0.7083889416235369
#   gamma: 0.01
#   max_iters: 500
#   batch_size: 512
#   reg_norm: 0.01
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100

# %%
#0.01
#  max_iters: 1500
#  batch_size: 256
#  reg_norm: 0.2
#  DICT AUGMENTED
X_train, features = X_preprocessing(x_train, features)
X_train_balanced, Y_train_balanced = balance_dataset(X_train, Y_train)
X_train_transformed = transform_features_column_median(X_train_balanced, features_dict_big, features)

gamma_values = [ 0.01 ]  # Learning rate
max_iters_values = [1500,2000]  # Number of iterations
l2_reg_values = [0.2, 0.3]  # L2 regularization parameter
batch_size_values = [128,  256,]  # Batch sizes for SGD
prob_threshold_values = [0.5]
beta1_values = [0.9]
beta2_values = [0.98]
decay_rates = [0.96]
decay_step_values = [100]

# Initialize a list to store results for each combination
grid_search_results = []
K = 5


# Perform grid search
for gamma, max_iters, batch, param_l2, prob_threshold, beta1, beta2, decay_rate, decay_steps in itertools.product(
        gamma_values, max_iters_values, batch_size_values, l2_reg_values,  prob_threshold_values, beta1_values, beta2_values, decay_rates, decay_step_values):
    
    # Run evaluation with current parameter combination
    F1_score = K_fold_cross_validation_f1_score(X_train_transformed, Y_train_balanced, K, 
       seed=5,
       max_iters=max_iters,
       gamma=gamma,
       reg_norm= ['l2',param_l2],
       prob_threshold=prob_threshold,
       batch_size=batch,
       beta1=beta1,
        beta2=beta2,
        decay_rate=decay_rate, 
        decay_steps=decay_steps
    )

    

    # Store the result and parameters for analysis
    grid_search_results.append({
        'gamma': gamma,
        'max_iters': max_iters,
        'batch_size': batch, 
        'reg_norm': param_l2,
        'prob_threshold': prob_threshold,
        'beta1': beta1,
        'beta2': beta2,
        'decay_rate': decay_rate,
        'decay_steps': decay_steps,
        'F1_score': F1_score
    })
# Out:
# C:\Users\beaiz\AppData\Local\Temp\ipykernel_27308\1134805394.py:1172: RuntimeWarning: Mean of empty slice
#   average_column = np.nanmean(selected_columns, axis=1)
# 100%|██████████| 5/5 [04:26<00:00, 53.28s/it]
# 100%|██████████| 5/5 [04:10<00:00, 50.18s/it]
# 100%|██████████| 5/5 [04:05<00:00, 49.18s/it]
# 100%|██████████| 5/5 [04:14<00:00, 50.97s/it]
# 100%|██████████| 5/5 [06:58<00:00, 83.65s/it]
# 100%|██████████| 5/5 [07:01<00:00, 84.24s/it]
# 100%|██████████| 5/5 [05:38<00:00, 67.67s/it]
# 100%|██████████| 5/5 [05:42<00:00, 68.55s/it]

# %%
# Sort grid search results by F1_score in descending order (best to worst)
sorted_results = sorted(grid_search_results, key=lambda x: x['F1_score'], reverse=True)

# Display sorted results
for i, result in enumerate(sorted_results):
    print(f"Rank {i+1}:")
    print(f"  F1_score: {result['F1_score']}")
    print(f"  gamma: {result['gamma']}")
    print(f"  max_iters: {result['max_iters']}")
    print(f"  batch_size: {result['batch_size']}")
    print(f"  reg_norm: {result['reg_norm']}")
    print(f"  prob_threshold: {result['prob_threshold']}")
    print(f"  beta1: {result['beta1']}")
    print(f"  beta2: {result['beta2']}")
    print(f"  decay_rate: {result['decay_rate']}")
    print(f"  decay_steps: {result['decay_steps']}")
    print("\n")
# Out:
# Rank 1:
#   F1_score: 0.7311078916069256
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.3
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 2:
#   F1_score: 0.7310476815563055
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 3:
#   F1_score: 0.7211102721170545
#   gamma: 0.01
#   max_iters: 2000
#   batch_size: 128
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 4:
#   F1_score: 0.7208300146363207
#   gamma: 0.01
#   max_iters: 2000
#   batch_size: 128
#   reg_norm: 0.3
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 5:
#   F1_score: 0.7144461458001349
#   gamma: 0.01
#   max_iters: 2000
#   batch_size: 256
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 6:
#   F1_score: 0.7141984330586073
#   gamma: 0.01
#   max_iters: 2000
#   batch_size: 256
#   reg_norm: 0.3
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 7:
#   F1_score: 0.7122066593755237
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 128
#   reg_norm: 0.3
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 8:
#   F1_score: 0.712097347399107
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 128
#   reg_norm: 0.2
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100

# %%
#0.01
#  max_iters: 1500
#  batch_size: 256
#  reg_norm: 0.2
#  DICT AUGMENTED
X_train, features = X_preprocessing(x_train, features)
X_train_balanced, Y_train_balanced = balance_dataset(X_train, Y_train)
X_train_transformed = transform_features_column_median(X_train_balanced, features_dict_big, features)

gamma_values = [ 0.01, 0.02 ]  # Learning rate
max_iters_values = [1500,]  # Number of iterations
l2_reg_values = [0.5, 0.4]  # L2 regularization parameter
batch_size_values = [ 256,512]  # Batch sizes for SGD
prob_threshold_values = [0.5]
beta1_values = [0.9]
beta2_values = [0.98]
decay_rates = [0.96]
decay_step_values = [100]

# Initialize a list to store results for each combination
grid_search_results = []
K = 5


# Perform grid search
for gamma, max_iters, batch, param_l2, prob_threshold, beta1, beta2, decay_rate, decay_steps in itertools.product(
        gamma_values, max_iters_values, batch_size_values, l2_reg_values,  prob_threshold_values, beta1_values, beta2_values, decay_rates, decay_step_values):
    
    # Run evaluation with current parameter combination
    F1_score = K_fold_cross_validation_f1_score(X_train_transformed, Y_train_balanced, K, 
       seed=5,
       max_iters=max_iters,
       gamma=gamma,
       reg_norm= ['l2',param_l2],
       prob_threshold=prob_threshold,
       batch_size=batch,
       beta1=beta1,
        beta2=beta2,
        decay_rate=decay_rate, 
        decay_steps=decay_steps
    )

    

    # Store the result and parameters for analysis
    grid_search_results.append({
        'gamma': gamma,
        'max_iters': max_iters,
        'batch_size': batch, 
        'reg_norm': param_l2,
        'prob_threshold': prob_threshold,
        'beta1': beta1,
        'beta2': beta2,
        'decay_rate': decay_rate,
        'decay_steps': decay_steps,
        'F1_score': F1_score
    })
# Out:
# C:\Users\beaiz\AppData\Local\Temp\ipykernel_27308\1134805394.py:1172: RuntimeWarning: Mean of empty slice
#   average_column = np.nanmean(selected_columns, axis=1)
# 100%|██████████| 5/5 [04:19<00:00, 51.92s/it]
# 100%|██████████| 5/5 [04:14<00:00, 50.85s/it]
# 100%|██████████| 5/5 [03:39<00:00, 43.94s/it]
# 100%|██████████| 5/5 [03:39<00:00, 43.99s/it]
# 100%|██████████| 5/5 [04:12<00:00, 50.41s/it]
# 100%|██████████| 5/5 [03:52<00:00, 46.45s/it]
# 100%|██████████| 5/5 [03:15<00:00, 39.07s/it]
# 100%|██████████| 5/5 [03:52<00:00, 46.49s/it]

# %%
# Sort grid search results by F1_score in descending order (best to worst)
sorted_results = sorted(grid_search_results, key=lambda x: x['F1_score'], reverse=True)

# Display sorted results
for i, result in enumerate(sorted_results):
    print(f"Rank {i+1}:")
    print(f"  F1_score: {result['F1_score']}")
    print(f"  gamma: {result['gamma']}")
    print(f"  max_iters: {result['max_iters']}")
    print(f"  batch_size: {result['batch_size']}")
    print(f"  reg_norm: {result['reg_norm']}")
    print(f"  prob_threshold: {result['prob_threshold']}")
    print(f"  beta1: {result['beta1']}")
    print(f"  beta2: {result['beta2']}")
    print(f"  decay_rate: {result['decay_rate']}")
    print(f"  decay_steps: {result['decay_steps']}")
    print("\n")
# Out:
# Rank 1:
#   F1_score: 0.7306400959844421
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.5
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 2:
#   F1_score: 0.7305334126003304
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.4
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 3:
#   F1_score: 0.7300047780160678
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.4
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 4:
#   F1_score: 0.7299970513722146
#   gamma: 0.01
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.5
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 5:
#   F1_score: 0.7253710446004609
#   gamma: 0.02
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.4
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 6:
#   F1_score: 0.7253204905696442
#   gamma: 0.02
#   max_iters: 1500
#   batch_size: 512
#   reg_norm: 0.5
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 7:
#   F1_score: 0.7181656741150497
#   gamma: 0.02
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.5
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
#
#
# Rank 8:
#   F1_score: 0.7181437713263631
#   gamma: 0.02
#   max_iters: 1500
#   batch_size: 256
#   reg_norm: 0.4
#   prob_threshold: 0.5
#   beta1: 0.9
#   beta2: 0.98
#   decay_rate: 0.96
#   decay_steps: 100
